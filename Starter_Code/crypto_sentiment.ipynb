# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jacobjalomo/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
news_key = os.getenv("NEWS_API_KEY")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=news_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_headlines = newsapi.get_everything(
    q="bitcoin", language="en", sort_by="relevancy"
)
bitcoin_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 7990,
#  'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'https://www.engadget.com/about/editors/steve-dent',
#    'title': 'Tesla now accepts Bitcoin in the US',
#    'description': "As it promised earlier this year, Tesla now accepts payment in Bitcoin, according to Tesla's website and a tweet from CEO Elon Musk.",
#    'url': 'https://www.engadget.com/tesla-will-soon-let-you-buy-one-of-its-e-vs-with-bitcoin-082916783.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-03/d3bc78e0-8116-11eb-87fb-7bddf8711d48',
#    'publishedAt': '2021-03-24T08:29:16Z',
#    'content': 'As it promised earlier this year, Tesla now accepts payment in Bitcoin, according to Tesla\'s website and a tweet from CEO Elon Musk. In a subsequent tweet, Musk said that "Bitcoin paid to Tesla will … [+1390 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Stan Schroeder',
#    'title': 'You can now buy a Tesla with Bitcoin, Elon Musk says',
#    'description': 'The inevitable has happened: You can now purchase a Tesla vehicle with Bitcoin.\xa0\nThis is according to Tesla CEO, pardon, Technoking Elon Musk, who tweeted it on Wednesday.\xa0\n\nYou can now buy a Tesla with Bitcoin\r\n\n— Elon Musk (@elonmusk) March 24, 2021\r\n\n\r\n\nTe…',
#    'url': 'https://mashable.com/article/elon-musk-tesla-bitcoin/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F03%252F24%252F4c%252F5e557a4d5d144e0898e8f087466d455a.46b57.jpg%252F1200x630.jpg?signature=O7ZjxA7YXNEMQMd0_p1tOsVA6iY=',
#    'publishedAt': '2021-03-24T08:10:09Z',
#    'content': 'The inevitable has happened: You can now purchase a Tesla vehicle with Bitcoin.\xa0\r\nThis is according to Tesla CEO, pardon, Technoking Elon Musk, who tweeted it on Wednesday.\xa0\r\nYou can now buy a Tesla … [+1648 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Darrell Etherington',
#    'title': 'Elon Musk declares you can now buy a Tesla with Bitcoin in the U.S.',
#    'description': 'Tesla made headlines earlier this year when it took out significant holdings in bitcoin, acquiring a roughly $1.5 billion stake at then-prices in early February. At the time, it also noted in an SEC filing disclosing the transaction that it could also eventua…',
#    'url': 'http://techcrunch.com/2021/03/24/elon-musk-declares-you-can-now-buy-a-tesla-with-bitcoin-in-the-u-s/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/02/tesla-bitcoin-alt.jpg?w=711',
#    'publishedAt': '2021-03-24T11:55:49Z',
#    'content': 'Tesla made headlines earlier this year when it took out significant holdings in bitcoin, acquiring a roughly $1.5 billion stake at then-prices in early February. At the time, it also noted in an SEC … [+2071 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Adi Robertson',
#    'title': 'India will reportedly introduce bill to make owning cryptocurrency illegal',
#    'description': 'India’s legislature is reportedly considering a near-total ban on private cryptocurrencies like Bitcoin or Ethereum, including owning the virtual currency. The government has discussed plans for a national digital currency as an alternative.',
#    'url': 'https://www.theverge.com/2021/3/15/22332677/india-cryptocurrency-trading-mining-possession-ban-law-report',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/IdgNJaOIQBsN8QbQcH2MDU6sAUA=/0x243:2040x1311/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/10432811/mdoying_180308_2373_0091still.jpg',
#    'publishedAt': '2021-03-15T22:25:02Z',
#    'content': 'One of the strictest crackdowns worldwide\r\nPhoto by Michele Doying / The Verge\r\nIndia is reportedly moving forward with a sweeping ban on cryptocurrencies. According to Reuters, the countrys legislat… [+1656 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': '(Deleted account)',
#    'title': 'Teen hacker behind the big Twitter hack sentenced to 3 years in prison',
#    'description': 'The hacker behind last year’s big Twitter hack\r\n has just been sentenced to hard time.\nGraham Ivan Clark, the teenage hacker who broke\r\n into Twitter’s systems, took over verified accounts, and used them to scam users out of Bitcoin, was sentenced to three ye…',
#    'url': 'https://mashable.com/article/teen-twitter-hacker-prison/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F03%252F16%252Fde%252F17c7b97375614eff9a3101c524b8bdc7.3ddd9.jpg%252F1200x630.jpg?signature=hVkjCyubP0Ak6Mnye3LA3kpUeCE=',
#    'publishedAt': '2021-03-16T21:40:35Z',
#    'content': 'The hacker behind last years big Twitter hack\r\n has just been sentenced to hard time.\r\nGraham Ivan Clark, the teenage hacker who broke\r\n into Twitters systems, took over verified accounts, and used t… [+2552 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Jack Morse',
#    'title': 'Coinbase says unmasking Satoshi Nakamoto might harm its business',
#    'description': 'Some things are best left a mystery — at least as far as Coinbase is concerned.\xa0\nThe San Francisco-based cryptocurrency exchange has been preparing to go public since last year, and in a Thursday prospectus filed with the Securities and Exchange Commission (S…',
#    'url': 'https://mashable.com/article/coinbase-direct-listing-unmasking-bitcoin-creator-satoshi-nakamoto/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F02%252F26%252Fe8%252F17dd59c8ab704170bf5e29da12d9ebbf.c6b86.jpg%252F1200x630.jpg?signature=Fs2g1MN2HN_UfNi1kogIjVxyo8E=',
#    'publishedAt': '2021-02-26T00:40:52Z',
#    'content': 'Some things are best left a mystery at least as far as Coinbase is concerned.\xa0\r\nThe San Francisco-based cryptocurrency exchange has been preparing to go public since last year, and in a Thursday pros… [+1953 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': None,
#    'title': 'Why bitcoin could triple over next year',
#    'description': "William Quigley, managing director of Magnetic, explains why he believes that bitcoin's value can still rise dramatically into 2022.",
#    'url': 'https://www.cnn.com/videos/business/2021/03/03/bitcoin-crypto-william-quigley-markets-now.cnn-business',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210219081655-02-bitcoin-file-super-tease.jpg',
#    'publishedAt': '2021-03-03T19:10:57Z',
#    'content': ''},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Jae Thomas',
#    'title': "Here's how you could win $8,000 in Bitcoin, investing classes, and more",
#    'description': 'TL;DR: Enter the The Complete Bitcoin (BTC) Investment Giveaway for a chance to win over $12,000 in cryptocurrency-related prizes.\n\nThe Bitcoin Investment Giveaway includes everything you need to get started in cryptocurrency investing, plus a detailed course…',
#    'url': 'https://mashable.com/shopping/feb-25-complete-bitcoin-investment-giveaway/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F02%252F25%252F29%252F527b6993551b4cdc867d406a408b92ea.8fc87.jpg%252F1200x630.jpg?signature=LuzW91oYqNerruEfoWyFEZR52oY=',
#    'publishedAt': '2021-02-25T10:00:00Z',
#    'content': 'TL;DR: Enter the The Complete Bitcoin (BTC) Investment Giveaway for a chance to win over $12,000 in cryptocurrency-related prizes.\r\nThe Bitcoin Investment Giveaway includes everything you need to get… [+1641 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Matt Novak',
#    'title': 'India Looks to Criminalize Trading, Mining, and Holding Cryptocurrencies: Report',
#    'description': 'A proposed law in India would make it a crime to mine, trade, or even hold cryptocurrencies like bitcoin in the country, according to a new report from Reuters citing a senior government official. It’s estimated roughly 8 million people in India hold some for…',
#    'url': 'https://gizmodo.com/india-looks-to-criminalize-trading-mining-and-holding-1846475775',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/uvoltaxovjhfhb5x5ozr.jpg',
#    'publishedAt': '2021-03-15T09:15:00Z',
#    'content': 'A proposed law in India would make it a crime to mine, trade, or even hold cryptocurrencies like bitcoin in the country, according to a new report from Reuters citing a senior government official. It… [+1725 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Alex Wilhelm',
#    'title': 'Coinbase files to go public in a key listing for the cryptocurrency category',
#    'description': 'This morning Coinbase, an American cryptocurrency exchange, released an S-1 filing ahead of its direct listing. The company’s public debut has been hotly anticipated thanks to recent activity amongst bitcoin and other blockchain-based assets, the company’s co…',
#    'url': 'http://techcrunch.com/2021/02/25/coinbase-files-to-go-public-in-a-key-listing-for-the-cryptocurrency-category/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/12/GettyImages-1028811312.jpg?w=650',
#    'publishedAt': '2021-02-25T13:23:28Z',
#    'content': 'This morning Coinbase, an American cryptocurrency exchange, released an S-1 filing ahead of its direct listing. The company’s public debut has been hotly anticipated thanks to recent activity amongst… [+2409 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'MicroStrategy buys 205 bitcoin for $10 million - Reuters',
#    'description': 'MicroStrategy Inc, a major corporate backer of bitcoin, has bought about 205 bitcoin for about $10 million in cash, it said on Friday, adding to its already substantial holdings of the cryptocurrency.',
#    'url': 'https://www.reuters.com/article/us-crypto-currency-microstrategy-idUSKBN2AX1F6',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210305&t=2&i=1553866737&r=LYNXMPEH240TQ&w=800',
#    'publishedAt': '2021-03-05T13:23:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: A collection of bitcoin (virtual currency) tokens are displayed in this picture illustration taken Dec. 8, 2017. REUTERS/Benoit Tessier/Illustration\r\n(Reuters) - MicroSt… [+905 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'MicroStrategy bitcoin holding valued at $4.38 billion after latest buy - Reuters',
#    'description': "Major bitcoin corporate backer MicroStrategy Inc said on Monday it bought another 328 bitcoin for about $15 million in cash, swelling its holdings of the cryptocurrency and sending the company's shares 7% higher in premarket trading.",
#    'url': 'https://www.reuters.com/article/us-crypto-currency-microstrategy-idUSKCN2AT2H5',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210301&t=2&i=1553322482&r=LYNXNPEH201G5&w=800',
#    'publishedAt': '2021-03-01T13:35:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of virtual currency Bitcoin are placed on a computer motherboard in this illustration taken January 21, 2021. REUTERS/Dado Ruvic/Illustration\r\n(Reuters) … [+1303 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Breakingviews - Capital Calls: China digs bitcoin hole - Reuters',
#    'description': 'Breakingviews - Capital Calls: China digs bitcoin hole\xa0\xa0Reuters',
#    'url': 'https://www.reuters.com/article/us-global-finance-breakingviews-idUSKCN2AU123',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210302&t=2&i=1553439612&r=LYNXNPEH210LQ&w=800',
#    'publishedAt': '2021-03-02T10:51:00Z',
#    'content': 'By Reuters Staff\r\nCryptocurrency mining facilities are seen in Pristina, Kosovo June 12, 2018.\r\nHONG KONG (Reuters Breakingviews) - Concise insights on global finance in the Covid-19 era.\r\nSUPPLY-SID… [+1621 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur en Español',
#    'title': 'Bitcoin could cost 6 million Mexican pesos, but the fall will be brutal and will last for years, says cryptocurrency expert',
#    'description': "Bobby Lee, co-founder of cryptocurrency exchange BTCC, predicts that the Bitcoin 'bubble' will burst after reaching its peak, which is known as 'Bitcoin winter'.",
#    'url': 'https://www.entrepreneur.com/article/367763',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1616529491-Mar23Bitcoinpodrallegaralos300mildlaresPORT.jpeg',
#    'publishedAt': '2021-03-23T20:23:00Z',
#    'content': 'March\r\n23, 2021\r\n3 min read\r\nThis article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\r\nAfter analyzing the history of the growth Bitcoin , exp… [+2236 chars]'},
#   {'source': {'id': None, 'name': 'The Motley Fool Canada'},
#    'author': None,
#    'title': 'Why Bitcoin Is Down Big Today - The Motley Fool Canada',
#    'description': '<ol><li>Why Bitcoin Is Down Big Today\xa0\xa0The Motley Fool Canada\r\n</li><li>Elon Musk, Bill Gates and Janet Yellen are sending bitcoin tumbling\xa0\xa0CTV News\r\n</li><li>Tesla, now strongly linked to bitcoin, drops in value as cryptocurrency plummets\xa0\xa0CBC.ca\r\n</li><li>…',
#    'url': 'https://www.fool.ca/2021/02/23/why-bitcoin-is-down-big-today/',
#    'urlToImage': 'https://yw553ftvhw1iqegz29fycoyw-wpengine.netdna-ssl.com/wp-content/uploads/2018/05/Bitcoin1.jpg',
#    'publishedAt': '2021-02-24T00:32:24Z',
#    'content': 'The cryptocurrency market has encountered major headwinds to open the final trading week of February. It is not the only sector that has been impacted. North American stocks were down broadly in mid-… [+3563 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bitcoin hits record high; trades as high as $59,755 on Saturday - Reuters',
#    'description': "Bitcoin, the world's biggest cryptocurrency, on Saturday reached a record high, trading up to $59,755.",
#    'url': 'https://www.reuters.com/article/us-crypto-currency-bitcoin-idUSKBN2B50B1',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210313&t=2&i=1554771186&r=LYNXMPEH2C07M&w=800',
#    'publishedAt': '2021-03-13T11:18:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency Bitcoin and U.S. One Dollar banknotes are seen in front of a stock graph in this illustration taken January 8, 2021. REUTERS/Dado Ru… [+440 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bitcoin hits $60,000 in record high - Reuters',
#    'description': "Bitcoin, the world's biggest cryptocurrency, on Saturday crossed a record high of $60,000.",
#    'url': 'https://www.reuters.com/article/us-crypto-currency-bitcoin-high-idUSKBN2B50BV',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210313&t=2&i=1554772780&r=LYNXMPEH2C083&w=800',
#    'publishedAt': '2021-03-13T11:54:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of virtual currency Bitcoin and U.S. dollar banknotes are seen in this picture illustration taken January 27, 2020. REUTERS/Dado Ruvic/Illustration\r\n(Reu… [+96 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Isabelle Lee',
#    'title': 'CBOE files for approval to list the first US bitcoin ETF',
#    'description': "Summary List PlacementThe Chicago Board Options Exchange has filed a request with the US Securities and Exchange Commission seeking approval to list shares of asset manager VanEck's bitcoin exchange-traded fund, in the latest attempt to launch a bitcoin ETF i…",
#    'url': 'https://markets.businessinsider.com/currencies/news/bitcoin-etf-btc-van-eck-cboe-files-for-approval-sec-2021-3-1030141735',
#    'urlToImage': 'https://images2.markets.businessinsider.com/603e69ee87d37600190d0a63?format=jpeg',
#    'publishedAt': '2021-03-02T16:54:51Z',
#    'content': 'Bitcoin.\r\nKTS Design/Science Photo Library/Getty Images\r\nThe Chicago Board Options Exchange has filed a request with the US Securities and Exchange Commission seeking approval to list shares of asset… [+1567 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Richard Lawler',
#    'title': "Right-wing site Gab responds to 'alleged' data breach",
#    'description': 'The CEO of Gab — the right-wing haven that lost mainstream tech backing after violent attacks in 2018 — published a curious blog post denying that the company has suffered a data breach. While it mysteriously went offline for a short time a week ago, at the t…',
#    'url': 'https://www.engadget.com/gab-data-breach-ddosecrets-231959411.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/O3qfGUMuAS1B2cCtlbwdSg--~B/aD0yMzEwO3c9MzAwMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2021-02/cc7cabe0-7888-11eb-9d7f-45cbe21e2ab8.cf.jpg',
#    'publishedAt': '2021-02-26T23:19:59Z',
#    'content': 'The CEO of Gab the right-wing haven that lost mainstream tech backing after violent attacks in 2018 published a curious blog post denying that the company has suffered a data breach. While it mysteri… [+894 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bitcoin rises 5% to $50,942.58 - Reuters UK',
#    'description': 'Bitcoin rose 5% to $50,942.58 on Wednesday, adding $2,426.23 to its previous close.',
#    'url': 'https://www.reuters.com/article/us-crypto-currency-bitcoin-idUSKBN2AV2X6',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210303&t=2&i=1553669467&r=LYNXMPEH221OB&w=800',
#    'publishedAt': '2021-03-03T22:48:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: A collection of bitcoin (virtual currency) tokens are displayed in this picture illustration taken Dec. 8, 2017. REUTERS/Benoit Tessier/Illustration\r\n(Reuters) - Bitcoin… [+642 chars]'}]}

# %%
# Fetch the Ethereum news articles
ethereum_headlines = newsapi.get_everything(
    q="ethereum", language="en", sort_by="relevancy"
)
ethereum_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 2266,
#  'articles': [{'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Adi Robertson',
#    'title': 'India will reportedly introduce bill to make owning cryptocurrency illegal',
#    'description': 'India’s legislature is reportedly considering a near-total ban on private cryptocurrencies like Bitcoin or Ethereum, including owning the virtual currency. The government has discussed plans for a national digital currency as an alternative.',
#    'url': 'https://www.theverge.com/2021/3/15/22332677/india-cryptocurrency-trading-mining-possession-ban-law-report',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/IdgNJaOIQBsN8QbQcH2MDU6sAUA=/0x243:2040x1311/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/10432811/mdoying_180308_2373_0091still.jpg',
#    'publishedAt': '2021-03-15T22:25:02Z',
#    'content': 'One of the strictest crackdowns worldwide\r\nPhoto by Michele Doying / The Verge\r\nIndia is reportedly moving forward with a sweeping ban on cryptocurrencies. According to Reuters, the countrys legislat… [+1656 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Justine Calma',
#    'title': 'The climate controversy swirling around NFTs',
#    'description': 'Most NFTs are bought and sold with Ethereum, a cryptocurrency that guzzles up energy and pumps out a lot of greenhouse gas emissions. Artists are fighting over whether there can be a more sustainable future for crypto art.',
#    'url': 'https://www.theverge.com/2021/3/15/22328203/nft-cryptoart-ethereum-blockchain-climate-change',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/pYrvxU6TUFVYkAwb6h1U4BPYMj0=/0x431:6000x3572/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22366636/1230723200.jpg',
#    'publishedAt': '2021-03-15T13:51:11Z',
#    'content': 'Famed auction house Christies just sold its first purely digital piece of art for a whopping $69 million. For that price, the buyer got a digital file of a collage of 5,000 images and a complex legac… [+12891 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Zack Whittaker',
#    'title': 'Roll still doesn’t know how its hot wallet was hacked',
#    'description': 'Move fast, break things, get hacked. That’s what happened at Roll, the social currency platform that allows creators to mint and distribute their own Ethereum-based cryptocurrency known as social tokens. Last week, Roll disclosed a hacker had stolen $5.7 mill…',
#    'url': 'http://techcrunch.com/2021/03/23/roll-still-doesnt-know-how-its-hot-wallet-was-hacked/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/03/containers-boxes-blow-up.jpg?w=711',
#    'publishedAt': '2021-03-23T17:16:30Z',
#    'content': 'Move fast, break things, get hacked.\r\nThat’s what happened at Roll, the social currency platform that allows creators to mint and distribute their own Ethereum-based cryptocurrency known as social to… [+3813 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': "Danica D'Souza",
#    'title': "A beginner's guide to NFTs, the crypto potentially worth millions",
#    'description': "Here's everything you need to know about non-fungible tokens, the latest cryptocurrency craze.\nRead the full story here. (And learn even more about NFTs here.)\xa0 Read more...More about Mashable Video, Blockchain, Ethereum, Cryptocurrency, and Nft",
#    'url': 'https://mashable.com/video/what-is-an-nft-explainer/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F03%252F16%252Fe1%252F03d4c959891a4bc4b6f9115746360a34.94b78.png%252F1200x630.png?signature=-pFRPpZyBXt2XETGtgHXvPcePz4=',
#    'publishedAt': '2021-03-16T18:30:28Z',
#    'content': "Here's everything you need to know about non-fungible tokens, the latest cryptocurrency craze.\r\nRead the full story here. (And learn even more about NFTs here.)"},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Lucas Matney',
#    'title': 'NFT marketplace OpenSea raises $23 million from a16z',
#    'description': 'OpenSea has been one of a handful of NFT marketplaces to explode in popularity in recent weeks as collectors wade into the trading of non-fungible tokens on the blockchain. While new startups have been popping up everyday, platforms that launched in crypto’s …',
#    'url': 'http://techcrunch.com/2021/03/18/nft-marketplace-opensea-raises-23-million-from-a16z/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/12/GettyImages-1160181732.jpg?w=600',
#    'publishedAt': '2021-03-18T19:57:38Z',
#    'content': 'OpenSea has been one of a handful of NFT marketplaces to explode in popularity in recent weeks as collectors wade into the trading of non-fungible tokens on the blockchain. While new startups have be… [+2529 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Stan Schroeder',
#    'title': 'What are NFTs? Everything you need to know.',
#    'description': 'NFTs are the latest cryptocurrency rage these days, with bands like Kings of Leon releasing their next album as limited edition "golden tickets," and NBA digital collectibles being sold for millions of dollars.\xa0\nThey\'re interesting to collectors and cryptocur…',
#    'url': 'https://mashable.com/article/nft-explainer-what-are-non-fungible-tokens/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F03%252F06%252F0e%252Fbd28ab464794471f9054bd26b9e0eda3.d0716.jpg%252F1200x630.jpg?signature=tS8_njLhE2SvWmtsr3QtFjqQHOA=',
#    'publishedAt': '2021-03-06T14:00:00Z',
#    'content': 'NFTs are the latest cryptocurrency rage these days, with bands like Kings of Leon releasing their next album as limited edition "golden tickets," and NBA digital collectibles being sold for millions … [+7287 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'David Riggs',
#    'title': 'If you haven’t followed NFTs, here’s why you should start',
#    'description': 'Digital content has value, and crypto collectors are flocking to lay their namesake on the biggest collections of tomorrow.',
#    'url': 'http://techcrunch.com/2021/02/27/if-you-havent-followed-nfts-heres-why-you-should-start/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2018/03/gettyimages-883634210.jpg?w=574',
#    'publishedAt': '2021-02-27T13:26:25Z',
#    'content': 'NFTs (non-fungible tokens) — or scarce digital content represented as tokens — are driving a new wave of crypto adoption.\r\nThanks to the Ethereum blockchain, artists, gaming companies and content cre… [+5365 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Stan Schroeder',
#    'title': 'Crypto wallet MetaMask now lets you swap tokens on your phone',
#    'description': "MetaMask, one of the most popular web wallets for cryptocurrency platform Ethereum, went mobile on iOS and Android in September 2020. However, the mobile version wasn't updated at the same pace as the web version — in particular, the ability to exchange one c…",
#    'url': 'https://mashable.com/article/metamask-swaps/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F03%252F17%252F70%252Ff4c249ddc7404d84a6ec54aa02689419.07a92.png%252F1200x630.png?signature=OesoJsE5KfVRwuvmM2a_0WKHV8M=',
#    'publishedAt': '2021-03-17T16:00:00Z',
#    'content': "MetaMask, one of the most popular web wallets for cryptocurrency platform Ethereum, went mobile on iOS and Android in September 2020. However, the mobile version wasn't updated at the same pace as th… [+1807 chars]"},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Zack Whittaker',
#    'title': '$5.7M stolen in Roll crypto heist after hot wallet hacked',
#    'description': 'A security breach at cryptocurrency platform Roll allowed a hacker to obtain the private key to its hot wallet and steal its contents — worth about $5.7 million. In a statement, the company said it was investigating the breach, which happened early Sunday. “A…',
#    'url': 'http://techcrunch.com/2021/03/16/5-7m-stolen-in-roll-crypto-heist-after-hot-wallet-hacked/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/03/cryptocurrency-coins.jpg?w=600',
#    'publishedAt': '2021-03-16T14:19:24Z',
#    'content': 'A security breach at cryptocurrency platform Roll allowed a hacker to obtain the private key to its hot wallet and steal its contents worth about $5.7 million.\r\nIn a statement, the company said it wa… [+1908 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Jack Morse',
#    'title': 'Coinbase says unmasking Satoshi Nakamoto might harm its business',
#    'description': 'Some things are best left a mystery — at least as far as Coinbase is concerned.\xa0\nThe San Francisco-based cryptocurrency exchange has been preparing to go public since last year, and in a Thursday prospectus filed with the Securities and Exchange Commission (S…',
#    'url': 'https://mashable.com/article/coinbase-direct-listing-unmasking-bitcoin-creator-satoshi-nakamoto/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F02%252F26%252Fe8%252F17dd59c8ab704170bf5e29da12d9ebbf.c6b86.jpg%252F1200x630.jpg?signature=Fs2g1MN2HN_UfNi1kogIjVxyo8E=',
#    'publishedAt': '2021-02-26T00:40:52Z',
#    'content': 'Some things are best left a mystery at least as far as Coinbase is concerned.\xa0\r\nThe San Francisco-based cryptocurrency exchange has been preparing to go public since last year, and in a Thursday pros… [+1953 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Romain Dillet',
#    'title': 'Bitfinex launches cryptocurrency payment gateway for merchants',
#    'description': 'Cryptocurrency exchange company Bitfinex is launching Bitfinex Pay, a cryptocurrency payment gateway. With this new product, online merchants can accept payments in various cryptocurrencies. It should make cross-border transactions easier in particular. While…',
#    'url': 'http://techcrunch.com/2021/03/04/bitfinex-launches-cryptocurrency-payment-gateway-for-merchants/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/04/bitcoin-bitfinex.jpg?w=750',
#    'publishedAt': '2021-03-04T16:48:05Z',
#    'content': 'Cryptocurrency exchange company Bitfinex is launching Bitfinex Pay, a cryptocurrency payment gateway. With this new product, online merchants can accept payments in various cryptocurrencies. It shoul… [+1551 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Mike Winters on Two Cents, shared by Mike Winters to Lifehacker',
#    'title': 'Why NFT Collectibles Are Overhyped',
#    'description': 'NFTs have become an investing phenomenon, with everything from GIFs to sports highlights selling for millions of dollars. But how much of this is hype—and should we be reassured by celebrity endorsements from Logan Paul, Paris Hilton, Lindsay Lohan, Rob Gronk…',
#    'url': 'https://twocents.lifehacker.com/why-nft-collectibles-are-overhyped-1846452668',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/dclkyg7wdn18rjbbxbsw.png',
#    'publishedAt': '2021-03-11T01:35:00Z',
#    'content': 'NFTs have become an investing phenomenon, with everything from GIFs to sports highlights selling for millions of dollars. But how much of this is hypeand should we be reassured by celebrity endorseme… [+4477 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Chinese beauty app Meitu shares surge after cryptocurrency investment - Reuters',
#    'description': 'Shares of Hong Kong-listed Chinese photo editing app Meitu Inc rose as much as 14.4% on Monday morning after the company said it had bought $40 million of cryptocurrencies.',
#    'url': 'https://www.reuters.com/article/us-crypto-currency-meitu-idUSKBN2B007L',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210308&t=2&i=1554076870&r=LYNXMPEH2703Y&w=800',
#    'publishedAt': '2021-03-08T02:46:00Z',
#    'content': "By Reuters Staff\r\nFILE PHOTO: A logo of Meitu is displayed at a news conference on the company's results in Hong Kong, China March 24, 2017. REUTERS/Bobby Yip\r\nHONG KONG (Reuters) - Shares of Hong Ko… [+1180 chars]"},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Jae Thomas',
#    'title': "Here's how you could win $8,000 in Bitcoin, investing classes, and more",
#    'description': 'TL;DR: Enter the The Complete Bitcoin (BTC) Investment Giveaway for a chance to win over $12,000 in cryptocurrency-related prizes.\n\nThe Bitcoin Investment Giveaway includes everything you need to get started in cryptocurrency investing, plus a detailed course…',
#    'url': 'https://mashable.com/shopping/feb-25-complete-bitcoin-investment-giveaway/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F02%252F25%252F29%252F527b6993551b4cdc867d406a408b92ea.8fc87.jpg%252F1200x630.jpg?signature=LuzW91oYqNerruEfoWyFEZR52oY=',
#    'publishedAt': '2021-02-25T10:00:00Z',
#    'content': 'TL;DR: Enter the The Complete Bitcoin (BTC) Investment Giveaway for a chance to win over $12,000 in cryptocurrency-related prizes.\r\nThe Bitcoin Investment Giveaway includes everything you need to get… [+1641 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Romanian blockchain unicorn Elrond plans new features for money app - Reuters Canada',
#    'description': 'Romanian blockchain start-up Elrond is preparing to have its new global payments app support Bitcoin this month as it looks to rival more established rivals PayPal or Revolut, its CEO said, as it taps surging interest in crypto currencies.',
#    'url': 'https://www.reuters.com/article/us-romania-blockchain-elrond-idUSKBN2AV0VL',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210303&t=2&i=1553567790&r=LYNXMPEH220FG&w=800',
#    'publishedAt': '2021-03-03T09:20:00Z',
#    'content': 'By Reuters Staff\r\nBUCHAREST (Reuters) - Romanian blockchain start-up Elrond is preparing to have its new global payments app support Bitcoin this month as it looks to rival more established rivals Pa… [+1854 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Matt Novak',
#    'title': 'India Looks to Criminalize Trading, Mining, and Holding Cryptocurrencies: Report',
#    'description': 'A proposed law in India would make it a crime to mine, trade, or even hold cryptocurrencies like bitcoin in the country, according to a new report from Reuters citing a senior government official. It’s estimated roughly 8 million people in India hold some for…',
#    'url': 'https://gizmodo.com/india-looks-to-criminalize-trading-mining-and-holding-1846475775',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/uvoltaxovjhfhb5x5ozr.jpg',
#    'publishedAt': '2021-03-15T09:15:00Z',
#    'content': 'A proposed law in India would make it a crime to mine, trade, or even hold cryptocurrencies like bitcoin in the country, according to a new report from Reuters citing a senior government official. It… [+1725 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Oscar Gonzalez',
#    'title': 'NFTs explained: These pricey assets are as weird as you think they are - CNET',
#    'description': "Owning a digital copy of an expensive artwork or song doesn't mean you actually own the art or the song -- but those copies are still going for a small fortune.",
#    'url': 'https://www.cnet.com/news/nfts-explained-these-pricey-assets-are-as-weird-as-you-think-they-are/',
#    'urlToImage': 'https://cnet4.cbsistatic.com/img/CpsQ1YlDWlpuNn9-gvPv_kRGy68=/1200x630/2021/03/18/a220c8f8-8abf-4dc0-a8fe-210afe20389d/gettyimages-1052487852.jpg',
#    'publishedAt': '2021-03-18T17:28:00Z',
#    'content': "The band Kings of Leon sold its latest album via NFTs and made more than $2 million from the sales.\r\nGetty Images\r\nThere's a new way to spend your money -- or potentially earn big bucks -- that's out… [+6223 chars]"},
#   {'source': {'id': None, 'name': 'Videocardz.com'},
#    'author': None,
#    'title': 'GeForce RTX 3060 Ethereum Mining Restrictions Have Been Broken',
#    'description': 'Update: Two german publications have now confirmed Ethereum mining limiter can be removed simply by using a special driver. NVIDIA GeForce RTX 3060 Ethereum mining restrictions have been broken The editorial team from PC Watch confirms that a hack developed b…',
#    'url': 'https://videocardz.com/newz/pc-watch-geforce-rtx-3060-ethereum-mining-restrictions-have-been-broken',
#    'urlToImage': 'https://cdn.videocardz.com/1/2021/03/RTX-3060-Ethereum-1.jpg',
#    'publishedAt': '2021-03-16T12:03:43Z',
#    'content': 'Update: Two german publications have now confirmed Ethereum mining limiter can be removed simply by using a special driver.\r\nThe editorial team from PC Watch confirms that a hack developed by miners … [+2873 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'snagarajan@businessinsider.com (Shalini Nagarajan)',
#    'title': "The world's largest crypto fund manager is offering new trusts that invest in 5 different cryptocurrencies",
#    'description': 'The new trusts will invest in Basic Attention and Decentraland tokens, plus Chainlink, Filecoin, and Livepeer.',
#    'url': 'https://www.businessinsider.com/grayscale-investments-launches-5-new-cryptocurrency-trusts-digital-investments-2021-3',
#    'urlToImage': 'https://i.insider.com/605322eef75f09001814e8fc?width=1200&format=jpeg',
#    'publishedAt': '2021-03-18T11:52:37Z',
#    'content': 'Digital currency asset manager Grayscale Investments announced Wednesday that it is offering five new investment trusts, bringing its single-asset lineup to 13.\r\nThe new trusts are launching into fai… [+2087 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Joseph Green',
#    'title': 'Learn all about Blockchain technology with this £20 course',
#    'description': "TL;DR: The Blockchain Certification Advanced Training Bundle is on sale for £20.60 as of Feb. 25, saving you 96% on list price.\n\nIf you've taken note of any trends in finance, technology, and investing over the past 10 years, you've probably noticed the rise …",
#    'url': 'https://mashable.com/uk/shopping/feb-25-blockchain-technology-certification-bundle-on-sale/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F02%252F25%252F1a%252F21ac42eacdf44c4e85755b1777d199c3.a29fe.jpg%252F1200x630.jpg?signature=v7N1jOZ9sdrislcqSb15IF5ue5o=',
#    'publishedAt': '2021-02-25T05:00:00Z',
#    'content': "TL;DR: The Blockchain Certification Advanced Training Bundle is on sale for £20.60 as of Feb. 25, saving you 96% on list price.\r\nIf you've taken note of any trends in finance, technology, and investi… [+4328 chars]"}]}

# %%
# Create the Bitcoin sentiment scores DataFrame
analyzer.polarity_scores(bitcoin_headlines['articles'][1]['description'])

bitcoin_sentiments = []

for article in bitcoin_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-03-24  As it promised earlier this year, Tesla now ac...    0.5859
# 1  2021-03-24  The inevitable has happened: You can now purch...    0.3182
# 2  2021-03-24  Tesla made headlines earlier this year when it...    0.2023
# 3  2021-03-15  One of the strictest crackdowns worldwide\r\nP...   -0.5574
# 4  2021-03-16  The hacker behind last years big Twitter hack\...   -0.5106
#
#    positive  negative  neutral
# 0     0.127     0.000    0.873
# 1     0.065     0.000    0.935
# 2     0.050     0.000    0.950
# 3     0.000     0.110    0.890
# 4     0.000     0.142    0.858

# %%
# Create the Ethereum sentiment scores DataFrame
analyzer.polarity_scores(ethereum_headlines['articles'][1]['description'])

ethereum_sentiments = []

for article in ethereum_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]

ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-03-15  One of the strictest crackdowns worldwide\r\nP...   -0.5574
# 1  2021-03-15  Famed auction house Christies just sold its fi...    0.0000
# 2  2021-03-23  Move fast, break things, get hacked.\r\nThat’s...   -0.4019
# 3  2021-03-16  Here's everything you need to know about non-f...   -0.1531
# 4  2021-03-18  OpenSea has been one of a handful of NFT marke...    0.4767
#
#    positive  negative  neutral
# 0     0.000     0.110    0.890
# 1     0.000     0.000    1.000
# 2     0.000     0.080    0.920
# 3     0.000     0.062    0.938
# 4     0.084     0.000    0.916

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.080030   0.055950   0.036900   0.857200
# std     0.440137   0.073811   0.080967   0.227188
# min    -0.906200   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.853000
# 50%     0.000000   0.025000   0.000000   0.901000
# 75%     0.348750   0.078250   0.016250   1.000000
# max     0.831600   0.246000   0.326000   1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         compound   positive   negative   neutral
# count  20.000000  20.000000  20.000000  20.00000
# mean    0.197020   0.076950   0.031150   0.89195
# std     0.406770   0.067969   0.047117   0.07006
# min    -0.557400   0.000000   0.000000   0.75400
# 25%    -0.038275   0.040500   0.000000   0.85600
# 50%     0.296000   0.077000   0.000000   0.91650
# 75%     0.449150   0.090250   0.066500   0.92750
# max     0.831600   0.246000   0.145000   1.00000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum.
#
# Q: Which coin had the highest compound score?
#
# A: They are the same.
#
# Q. Which coin had the highest positive score?
#
# A: They are the same.

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = stopwords.words('english')

# Expand the default stopwords list if necessary
sw.append('chars')
sw.append('char')

# %%
# Complete the tokenizer function
def tokenizer(text):
   
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
   
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase and cleaning up stop words
    # Remove stop words
    tokens = [word.lower() for word in lem if word.lower() not in sw]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
bitcoin_df['tokens'] = bitcoin_df.text.apply(tokenizer) 
bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-03-24  As it promised earlier this year, Tesla now ac...    0.5859
# 1  2021-03-24  The inevitable has happened: You can now purch...    0.3182
# 2  2021-03-24  Tesla made headlines earlier this year when it...    0.2023
# 3  2021-03-15  One of the strictest crackdowns worldwide\r\nP...   -0.5574
# 4  2021-03-16  The hacker behind last years big Twitter hack\...   -0.5106
#
#    positive  negative  neutral  \
# 0     0.127     0.000    0.873
# 1     0.065     0.000    0.935
# 2     0.050     0.000    0.950
# 3     0.000     0.110    0.890
# 4     0.000     0.142    0.858
#
#                                               tokens
# 0  [promised, earlier, year, tesla, accepts, paym...
# 1  [inevitable, ha, happened, purchase, tesla, ve...
# 2  [tesla, made, headline, earlier, year, took, s...
# 3  [one, strictest, crackdown, worldwidephoto, mi...
# 4  [hacker, behind, last, year, big, twitter, hac...

# %%
# Create a new tokens column for Ethereum
# Create a new tokens column for Bitcoin
ethereum_df['tokens'] = ethereum_df.text.apply(tokenizer) 
ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-03-15  One of the strictest crackdowns worldwide\r\nP...   -0.5574
# 1  2021-03-15  Famed auction house Christies just sold its fi...    0.0000
# 2  2021-03-23  Move fast, break things, get hacked.\r\nThat’s...   -0.4019
# 3  2021-03-16  Here's everything you need to know about non-f...   -0.1531
# 4  2021-03-18  OpenSea has been one of a handful of NFT marke...    0.4767
#
#    positive  negative  neutral  \
# 0     0.000     0.110    0.890
# 1     0.000     0.000    1.000
# 2     0.000     0.080    0.920
# 3     0.000     0.062    0.938
# 4     0.084     0.000    0.916
#
#                                               tokens
# 0  [one, strictest, crackdown, worldwidephoto, mi...
# 1  [famed, auction, house, christies, sold, first...
# 2  [move, fast, break, thing, get, hackedthats, h...
# 3  [heres, everything, need, know, nonfungible, t...
# 4  [opensea, ha, one, handful, nft, marketplace, ...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
bitcoin_count = [Counter(ngrams(tokens, n=2)) for tokens in bitcoin_df.tokens]
print(dict(bitcoin_count[0]))
# Out:
# {('promised', 'earlier'): 1, ('earlier', 'year'): 1, ('year', 'tesla'): 1, ('tesla', 'accepts'): 1, ('accepts', 'payment'): 1, ('payment', 'bitcoin'): 1, ('bitcoin', 'according'): 1, ('according', 'teslas'): 1, ('teslas', 'website'): 1, ('website', 'tweet'): 1, ('tweet', 'ceo'): 1, ('ceo', 'elon'): 1, ('elon', 'musk'): 1, ('musk', 'subsequent'): 1, ('subsequent', 'tweet'): 1, ('tweet', 'musk'): 1, ('musk', 'said'): 1, ('said', 'bitcoin'): 1, ('bitcoin', 'paid'): 1, ('paid', 'tesla'): 1}

# %%
# Generate the Ethereum N-grams where N=2
ethereum_count = [Counter(ngrams(tokens, n=2)) for tokens in ethereum_df.tokens]
print(dict(ethereum_count[0]))
# Out:
# {('one', 'strictest'): 1, ('strictest', 'crackdown'): 1, ('crackdown', 'worldwidephoto'): 1, ('worldwidephoto', 'michele'): 1, ('michele', 'doying'): 1, ('doying', 'vergeindia'): 1, ('vergeindia', 'reportedly'): 1, ('reportedly', 'moving'): 1, ('moving', 'forward'): 1, ('forward', 'sweeping'): 1, ('sweeping', 'ban'): 1, ('ban', 'cryptocurrencies'): 1, ('cryptocurrencies', 'according'): 1, ('according', 'reuters'): 1, ('reuters', 'country'): 1, ('country', 'legislat'): 1}

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
btctopten = []
for words in bitcoin_df.tokens:
    btctopten += words
bitcoin_top_ten = token_count(btctopten)
bitcoin_top_ten
# Out:
# [('bitcoin', 13),
#  ('reuters', 9),
#  ('ha', 8),
#  ('tesla', 6),
#  ('photo', 6),
#  ('stafffile', 5),
#  ('virtual', 5),
#  ('currency', 5),
#  ('illustration', 5),
#  ('taken', 5)]

# %%
# Use token_count to get the top 10 words for Ethereum
ethtopten = []
for words in ethereum_df.tokens:
    ethtopten += words
ethereum_top_ten = token_count(ethtopten)
ethereum_top_ten
# Out:
# [('cryptocurrency', 8),
#  ('new', 8),
#  ('reuters', 6),
#  ('digital', 5),
#  ('nfts', 5),
#  ('million', 4),
#  ('token', 4),
#  ('blockchain', 4),
#  ('company', 4),
#  ('bitcoin', 4)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wc_bitcoin = WordCloud().generate(bitcoin_df.text.str.cat())
plt.imshow(wc_bitcoin)

# %%
# Generate the Ethereum word cloud
wc_ethereum = WordCloud().generate(ethereum_df.text.str.cat())
plt.imshow(wc_ethereum)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
btc_text = bitcoin_df.text.str.cat()
btc_text
# Out:
# 'As it promised earlier this year, Tesla now accepts payment in Bitcoin, according to Tesla\'s website and a tweet from CEO Elon Musk. In a subsequent tweet, Musk said that "Bitcoin paid to Tesla will … [+1390 chars]The inevitable has happened: You can now purchase a Tesla vehicle with Bitcoin.\xa0\r\nThis is according to Tesla CEO, pardon, Technoking Elon Musk, who tweeted it on Wednesday.\xa0\r\nYou can now buy a Tesla … [+1648 chars]Tesla made headlines earlier this year when it took out significant holdings in bitcoin, acquiring a roughly $1.5 billion stake at then-prices in early February. At the time, it also noted in an SEC … [+2071 chars]One of the strictest crackdowns worldwide\r\nPhoto by Michele Doying / The Verge\r\nIndia is reportedly moving forward with a sweeping ban on cryptocurrencies. According to Reuters, the countrys legislat… [+1656 chars]The hacker behind last years big Twitter hack\r\n has just been sentenced to hard time.\r\nGraham Ivan Clark, the teenage hacker who broke\r\n into Twitters systems, took over verified accounts, and used t… [+2552 chars]Some things are best left a mystery at least as far as Coinbase is concerned.\xa0\r\nThe San Francisco-based cryptocurrency exchange has been preparing to go public since last year, and in a Thursday pros… [+1953 chars]TL;DR: Enter the The Complete Bitcoin (BTC) Investment Giveaway for a chance to win over $12,000 in cryptocurrency-related prizes.\r\nThe Bitcoin Investment Giveaway includes everything you need to get… [+1641 chars]A proposed law in India would make it a crime to mine, trade, or even hold cryptocurrencies like bitcoin in the country, according to a new report from Reuters citing a senior government official. It… [+1725 chars]This morning Coinbase, an American cryptocurrency exchange, released an S-1 filing ahead of its direct listing. The company’s public debut has been hotly anticipated thanks to recent activity amongst… [+2409 chars]By Reuters Staff\r\nFILE PHOTO: A collection of bitcoin (virtual currency) tokens are displayed in this picture illustration taken Dec. 8, 2017. REUTERS/Benoit Tessier/Illustration\r\n(Reuters) - MicroSt… [+905 chars]By Reuters Staff\r\nFILE PHOTO: Representations of virtual currency Bitcoin are placed on a computer motherboard in this illustration taken January 21, 2021. REUTERS/Dado Ruvic/Illustration\r\n(Reuters) … [+1303 chars]By Reuters Staff\r\nCryptocurrency mining facilities are seen in Pristina, Kosovo June 12, 2018.\r\nHONG KONG (Reuters Breakingviews) - Concise insights on global finance in the Covid-19 era.\r\nSUPPLY-SID… [+1621 chars]March\r\n23, 2021\r\n3 min read\r\nThis article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\r\nAfter analyzing the history of the growth Bitcoin , exp… [+2236 chars]The cryptocurrency market has encountered major headwinds to open the final trading week of February. It is not the only sector that has been impacted. North American stocks were down broadly in mid-… [+3563 chars]By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency Bitcoin and U.S. One Dollar banknotes are seen in front of a stock graph in this illustration taken January 8, 2021. REUTERS/Dado Ru… [+440 chars]By Reuters Staff\r\nFILE PHOTO: Representations of virtual currency Bitcoin and U.S. dollar banknotes are seen in this picture illustration taken January 27, 2020. REUTERS/Dado Ruvic/Illustration\r\n(Reu… [+96 chars]Bitcoin.\r\nKTS Design/Science Photo Library/Getty Images\r\nThe Chicago Board Options Exchange has filed a request with the US Securities and Exchange Commission seeking approval to list shares of asset… [+1567 chars]The CEO of Gab the right-wing haven that lost mainstream tech backing after violent attacks in 2018 published a curious blog post denying that the company has suffered a data breach. While it mysteri… [+894 chars]By Reuters Staff\r\nFILE PHOTO: A collection of bitcoin (virtual currency) tokens are displa ...

# %%
# Run the NER processor on all of the text
btc_NER = nlp(btc_text)

# Add a title to the document
btc_NER.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(btc_NER, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">As it promised
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earlier this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  now accepts payment in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , according to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's website and a tweet from CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . In a subsequent tweet,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said that &quot;Bitcoin paid to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  will … [+1390 chars]The inevitable has happened: You can now purchase a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  vehicle with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>This is according to Tesla CEO, pardon, Technoking
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who tweeted it on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>You can now buy a Tesla … [+1648 chars]Tesla made headlines
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earlier this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  when it took out significant holdings in bitcoin, acquiring a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     roughly $1.5 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  stake at then-prices in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     early February
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . At the time, it also noted in an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SEC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Photo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michele Doying
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is reportedly moving forward with a sweeping ban on cryptocurrencies. According to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the countrys legislat… [+1656 chars]The hacker behind
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  big
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Graham Ivan Clark
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br> into
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  systems, took over verified accounts, and used t… [+2552 chars]Some things are best left a mystery at least as far as
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6e

# %%
# List all Entities
def show_ents(btc_NER):
    if btc_NER.ents:
        for ent in btc_NER.ents:
            print(ent.text+' - '+ent.label_+' - '+str(spacy.explain(ent.label_)))
    else:
        print('No named entities found.')


show_ents(btc_NER)
# Out:
# earlier this year - DATE - Absolute or relative dates or periods
# Tesla - ORG - Companies, agencies, institutions, etc.
# Bitcoin - PERSON - People, including fictional
# Tesla - ORG - Companies, agencies, institutions, etc.
# Elon Musk - PERSON - People, including fictional
# Musk - PERSON - People, including fictional
# Tesla - ORG - Companies, agencies, institutions, etc.
# Tesla - ORG - Companies, agencies, institutions, etc.
# Bitcoin - PERSON - People, including fictional
# Elon Musk - PERSON - People, including fictional
# Wednesday - DATE - Absolute or relative dates or periods
# earlier this year - DATE - Absolute or relative dates or periods
# roughly $1.5 billion - MONEY - Monetary values, including unit
# early February - DATE - Absolute or relative dates or periods
# SEC - ORG - Companies, agencies, institutions, etc.
# Photo - PERSON - People, including fictional
# Michele Doying - PERSON - People, including fictional
# India - GPE - Countries, cities, states
# Reuters - ORG - Companies, agencies, institutions, etc.
# last years - DATE - Absolute or relative dates or periods
# Twitter - PRODUCT - Objects, vehicles, foods, etc. (not services)
# Graham Ivan Clark - PERSON - People, including fictional
# Twitters - NORP - Nationalities or religious or political groups
# Coinbase - NORP - Nationalities or religious or political groups
# San Francisco - GPE - Countries, cities, states
# last year - DATE - Absolute or relative dates or periods
# Thursday - DATE - Absolute or relative dates or periods
# over $12,000 - MONEY - Monetary values, including unit
# India - GPE - Countries, cities, states
# Reuters - ORG - Companies, agencies, institutions, etc.
# Coinbase - WORK_OF_ART - Titles of books, songs, etc.
# American - NORP - Nationalities or religious or political groups
# Reuters - ORG - Companies, agencies, institutions, etc.
# Dec. 8, 2017 - DATE - Absolute or relative dates or periods
# Benoit Tessier/Illustration - ORG - Companies, agencies, institutions, etc.
# Reuters - ORG - Companies, agencies, institutions, etc.
# Reuters - ORG - Companies, agencies, institutions, etc.
# Bitcoin - PERSON - People, including fictional
# January 21, 2021 - DATE - Absolute or relative dates or periods
# Reuters - ORG - Companies, agencies, institutions, etc.
# Reuters - ORG - Companies, agencies, institutions, etc.
# Pristina - GPE - Countries, cities, states
# Kosovo - GPE - Countries, cities, states
# June 12, 2018 - DATE - Absolute or relative dates or periods
# HONG KONG - GPE - Countries, cities, states
# Reuters Breakingviews - ORG - Companies, agencies, institutions, etc.
# 23, 2021 - DATE - Absolute or relative dates or periods
# Spanish - NORP - Nationalities or religious or political groups
# AI - ORG - Companies, agencies, institutions, etc.
# Bitcoin - PERSON - People, including fictional
# week of February - DATE - Absolute or relative dates or periods
# North American - NORP - Nationalities or religious or political groups
# Reuters - ORG - Companies, agencies, institutions, etc.
# Bitcoin - PERSON - People, including fictional
# U.S. - GPE - Countries, cities, states
# January 8, 2021 - DATE - Absolute or relative dates or periods
# Dado Ru - PERSON - People, including fictional
# Reuters - ORG - Companies, agencies, institutions, etc.
# Bitcoin - PERSON - People, including fictional
# U.S. - GPE - Countries, cities, states
# January 27, 2020 - DATE - Absolute or relative dates or periods
# KTS Design/Science Photo Library/Getty Images - ORG - Companies, agencies, institutions, etc.
# The Chicago Board Options Exchange - ORG - Companies, agencies, institutions, etc.
# the US Securities and Exchange Commission - ORG - Companies, agencies, institutions, etc.
# 2018 - DATE - Absolute or relative dates or periods
# Reuters - ORG - Companies, agencies, institutions, etc.
# Dec. 8, 2017 - DATE - Absolute or relative dates or periods
# Benoit Tessier/Illustration - ORG - Companies, agencies, institutions, etc.
# Reuters - ORG - Companies, agencies, institutions, etc.

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_text = ethereum_df.text.str.cat()
eth_text
# Out:
# 'One of the strictest crackdowns worldwide\r\nPhoto by Michele Doying / The Verge\r\nIndia is reportedly moving forward with a sweeping ban on cryptocurrencies. According to Reuters, the countrys legislat… [+1656 chars]Famed auction house Christies just sold its first purely digital piece of art for a whopping $69 million. For that price, the buyer got a digital file of a collage of 5,000 images and a complex legac… [+12891 chars]Move fast, break things, get hacked.\r\nThat’s what happened at Roll, the social currency platform that allows creators to mint and distribute their own Ethereum-based cryptocurrency known as social to… [+3813 chars]Here\'s everything you need to know about non-fungible tokens, the latest cryptocurrency craze.\r\nRead the full story here. (And learn even more about NFTs here.)OpenSea has been one of a handful of NFT marketplaces to explode in popularity in recent weeks as collectors wade into the trading of non-fungible tokens on the blockchain. While new startups have be… [+2529 chars]NFTs are the latest cryptocurrency rage these days, with bands like Kings of Leon releasing their next album as limited edition "golden tickets," and NBA digital collectibles being sold for millions … [+7287 chars]NFTs (non-fungible tokens) — or scarce digital content represented as tokens — are driving a new wave of crypto adoption.\r\nThanks to the Ethereum blockchain, artists, gaming companies and content cre… [+5365 chars]MetaMask, one of the most popular web wallets for cryptocurrency platform Ethereum, went mobile on iOS and Android in September 2020. However, the mobile version wasn\'t updated at the same pace as th… [+1807 chars]A security breach at cryptocurrency platform Roll allowed a hacker to obtain the private key to its hot wallet and steal its contents worth about $5.7 million.\r\nIn a statement, the company said it wa… [+1908 chars]Some things are best left a mystery at least as far as Coinbase is concerned.\xa0\r\nThe San Francisco-based cryptocurrency exchange has been preparing to go public since last year, and in a Thursday pros… [+1953 chars]Cryptocurrency exchange company Bitfinex is launching Bitfinex Pay, a cryptocurrency payment gateway. With this new product, online merchants can accept payments in various cryptocurrencies. It shoul… [+1551 chars]NFTs have become an investing phenomenon, with everything from GIFs to sports highlights selling for millions of dollars. But how much of this is hypeand should we be reassured by celebrity endorseme… [+4477 chars]By Reuters Staff\r\nFILE PHOTO: A logo of Meitu is displayed at a news conference on the company\'s results in Hong Kong, China March 24, 2017. REUTERS/Bobby Yip\r\nHONG KONG (Reuters) - Shares of Hong Ko… [+1180 chars]TL;DR: Enter the The Complete Bitcoin (BTC) Investment Giveaway for a chance to win over $12,000 in cryptocurrency-related prizes.\r\nThe Bitcoin Investment Giveaway includes everything you need to get… [+1641 chars]By Reuters Staff\r\nBUCHAREST (Reuters) - Romanian blockchain start-up Elrond is preparing to have its new global payments app support Bitcoin this month as it looks to rival more established rivals Pa… [+1854 chars]A proposed law in India would make it a crime to mine, trade, or even hold cryptocurrencies like bitcoin in the country, according to a new report from Reuters citing a senior government official. It… [+1725 chars]The band Kings of Leon sold its latest album via NFTs and made more than $2 million from the sales.\r\nGetty Images\r\nThere\'s a new way to spend your money -- or potentially earn big bucks -- that\'s out… [+6223 chars]Update: Two german publications have now confirmed Ethereum mining limiter can be removed simply by using a special driver.\r\nThe editorial team from PC Watch confirms that a hack developed by miners … [+2873 chars]Digital currency asset manager Grayscale Investments announced Wednesday that it is offering five new investment trusts, bringing its single-asset lineup to 13.\r\n ...

# %%
# Run the NER processor on all of the text
eth_NER = nlp(eth_text)

# Add a title to the document
eth_NER.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(eth_NER, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Photo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michele Doying
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is reportedly moving forward with a sweeping ban on cryptocurrencies. According to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the countrys legislat… [+1656 chars]Famed auction house
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  just sold its
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  purely digital piece of art for a whopping
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $69 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . For that price, the buyer got a digital file of a collage of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>That’s what happened at Roll, the social currency platform that allows creators to mint and distribute their own
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Read the full story here. (And learn even more about NFTs
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     here.)OpenSea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has been one of a handful of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  marketplaces to explode in popularity in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recent weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  as collectors wade into the trading of non-fungible tokens on the blockchain. While new startups have be… [+2529 chars]NFTs are the latest cryptocurrency rage
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     these days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , with bands like
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kings
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  of Leon releasing their next album as limited edition &quot;golden tickets,&quot; and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NBA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  digital collectibles being sold for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>Thanks to the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  blockchain, artists, gaming companies and content cre… [+5365
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chars]MetaMask
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the most popular web wallets for cryptocurrency platform
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , went mobile on iOS and Android in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . However, the mobile version wasn't updated at the same pace as th… [+1807 chars]A security breach at cryptocurrency platform Roll allowed a hacker to obtain the private key

# %%
# List all Entities
show_ents(eth_NER)
# Out:
# One - CARDINAL - Numerals that do not fall under another type
# Photo - PERSON - People, including fictional
# Michele Doying - PERSON - People, including fictional
# India - GPE - Countries, cities, states
# Reuters - ORG - Companies, agencies, institutions, etc.
# Christies - ORG - Companies, agencies, institutions, etc.
# first - ORDINAL - "first", "second", etc.
# $69 million - MONEY - Monetary values, including unit
# 5,000 - CARDINAL - Numerals that do not fall under another type
# Ethereum - ORG - Companies, agencies, institutions, etc.
# here.)OpenSea - GPE - Countries, cities, states
# NFT - ORG - Companies, agencies, institutions, etc.
# recent weeks - DATE - Absolute or relative dates or periods
# these days - DATE - Absolute or relative dates or periods
# Kings - PERSON - People, including fictional
# NBA - ORG - Companies, agencies, institutions, etc.
# millions - CARDINAL - Numerals that do not fall under another type
# Ethereum - ORG - Companies, agencies, institutions, etc.
# chars]MetaMask - ORG - Companies, agencies, institutions, etc.
# one - CARDINAL - Numerals that do not fall under another type
# Ethereum - ORG - Companies, agencies, institutions, etc.
# September 2020 - DATE - Absolute or relative dates or periods
# about $5.7 million - MONEY - Monetary values, including unit
# Coinbase - NORP - Nationalities or religious or political groups
# San Francisco - GPE - Countries, cities, states
# last year - DATE - Absolute or relative dates or periods
# Thursday - DATE - Absolute or relative dates or periods
# Bitfinex - ORG - Companies, agencies, institutions, etc.
# Bitfinex - ORG - Companies, agencies, institutions, etc.
# millions of dollars - MONEY - Monetary values, including unit
# Reuters - ORG - Companies, agencies, institutions, etc.
# Meitu - ORG - Companies, agencies, institutions, etc.
# Hong Kong - GPE - Countries, cities, states
# China - GPE - Countries, cities, states
# March 24, 2017 - DATE - Absolute or relative dates or periods
# Bobby Yip - PERSON - People, including fictional
# HONG KONG - GPE - Countries, cities, states
# Reuters - ORG - Companies, agencies, institutions, etc.
# Hong Ko - PERSON - People, including fictional
# over $12,000 - MONEY - Monetary values, including unit
# Reuters - ORG - Companies, agencies, institutions, etc.
# BUCHAREST - PERSON - People, including fictional
# Reuters - ORG - Companies, agencies, institutions, etc.
# this month - DATE - Absolute or relative dates or periods
# India - GPE - Countries, cities, states
# Reuters - ORG - Companies, agencies, institutions, etc.
# Kings - ORG - Companies, agencies, institutions, etc.
# Leon - PRODUCT - Objects, vehicles, foods, etc. (not services)
# more than $2 million - MONEY - Monetary values, including unit
# Getty Images - PERSON - People, including fictional
# Two - CARDINAL - Numerals that do not fall under another type
# Ethereum - PERSON - People, including fictional
# Grayscale Investments - ORG - Companies, agencies, institutions, etc.
# Wednesday - DATE - Absolute or relative dates or periods
# five - CARDINAL - Numerals that do not fall under another type
# 13 - CARDINAL - Numerals that do not fall under another type
# The Blockchain Certification Advanced Training Bundle - ORG - Companies, agencies, institutions, etc.
# 20.60 - MONEY - Monetary values, including unit
# as of Feb. 25 - DATE - Absolute or relative dates or periods
# 96% - PERCENT - Percentage, including "%"

# %% [markdown]
# ---
